# %% [markdown]
# # On-chain data — Scientific Data tutorial and author template
#
# **Responsibility:** Student A leads; Student B independently reproduces. **Evidence status:** SYNTHETIC teaching example; empirical author inputs remain incomplete.
#
# This notebook combines an executable miniature pipeline with instructions for a first-time student author. All records, dates, quantities, identifiers, relationships and review labels are invented. Do not cite them as findings for the project. The actual project is not implemented by entering names in an author worksheet.
#
# [Repository](https://github.com/sunshineluyao/Web3AI4IO-SD-Template) · [First-author guide](https://github.com/sunshineluyao/Web3AI4IO-SD-Template/blob/9af469f9ede69dc6ed3daef7fbc9fc5fe3d75f1d/docs/first_author_guide.md) · [Venue requirements and evidence](https://github.com/sunshineluyao/Web3AI4IO-SD-Template/blob/9af469f9ede69dc6ed3daef7fbc9fc5fe3d75f1d/docs/requirements.md)
#
# The eight-part structure is a teaching choice. It supports documentation against [Scientific Data guidance](https://www.nature.com/sdata/submission-guidelines), [NeurIPS dataset hosting](https://neurips.cc/Conferences/2026/EvaluationsDatasetsHosting), and the [NeurIPS checklist](https://neurips.cc/public/guides/PaperChecklist); it does not certify publication readiness.

# %% [markdown]
# <a id="part-i"></a>
# ## Part I — Overview and navigation
#
# Read the explanation before each code cell. Run a code cell with its play button or Shift+Enter; a number beside the cell means it ran. Use the table of contents to revisit a part. If an error occurs, read the final message, resolve the stated input/version issue and rerun from a fresh runtime when necessary.
#
# 1. [Overview](#part-i)
# 2. [Data sources, metadata and dictionary](#part-ii)
# 3. [Query or acquire data](#part-iii)
# 4. [Inspect queried data](#part-iv)
# 5. [Process data](#part-v)
# 6. [Inspect processed data](#part-vi)
# 7. [Analyze data for understanding and reuse](#part-vii)
# 8. [Technical validation and handoff](#part-viii)
#
# Open the downloaded .ipynb through Colab's upload option, or open its GitHub Colab link. Use **File → Save a copy in Drive** for your editable copy; share that copy with your coauthor. Select a Python CPU runtime and run from the beginning. No GPU, paid API, wallet, Drive mount or credential is needed for the included example. Runtime files are temporary; saving the notebook does not archive all generated files. See [Google's Colab FAQ](https://research.google.com/colaboratory/faq.html).

# %% [markdown]
# ### Learning objective and author entry
#
# Learn how a defined collection of blockchain-like events becomes an inspectable event dataset. Explain what is recorded by the chain, how a query selects it, and what remains unknown about actors or activity outside the selected scope.
#
# **AUTHOR INPUT — replace in the research tutorial:**
#
# | Entry | Your verified content |
# |---|---|
# | Project question and intended interdisciplinary users | AUTHOR INPUT |
# | Lead author, coauthor/reproducer, contact and date | AUTHOR INPUT |
# | What one record represents and eligible population | AUTHOR INPUT |
# | Scope, source dates, code commit and data revision | AUTHOR INPUT |
# | What users will reproduce and which claims remain unsupported | AUTHOR INPUT |
# | Actual download size, runtime, memory, hardware and access/cost | AUTHOR INPUT |
#
# The teaching pipeline uses Python 3.12 and its standard library. Notebook display uses IPython supplied by Colab. The setup prints the actual runtime; it does not claim to reproduce an unmeasured project environment.

# %% [markdown]
# ### Essential vocabulary
#
# | Term | Plain-language meaning |
# |---|---|
# | On-chain | Information recorded by a blockchain; this demo uses invented records, not a live chain. |
# | Block | A grouping of records identified by network-specific height/hash. |
# | Transaction and event log | A transaction may generate several logs; declare whether your observation is a transaction, log, contract, or another object. |
# | Canonicality/finality | Rules for whether a record belongs to the accepted chain history and when it is treated as stable. |
# | ABI/decoding | If applicable to the chosen chain, the specification used to interpret encoded contract outputs; actual versions must be supplied. |
#
# **AUTHOR INPUT:** Add the project-specific concepts a scholar from another discipline needs, define abbreviations on first use, and cite authoritative documentation for the actual sources and methods. [Integration agreement](https://github.com/sunshineluyao/Web3AI4IO-SD-Template/blob/9af469f9ede69dc6ed3daef7fbc9fc5fe3d75f1d/docs/integration_contract.md).

# %% [markdown]
# <a id="part-ii"></a>
# ## Part II — Data sources, metadata, dictionary and URLs
#
# Name each chain/network and source provider, endpoint documentation URL, API/schema version, contract selection rule, event type, block range, UTC date bounds, finality/reorg rule, pagination and completeness evidence. For real token values record raw integer amounts and the exact decimals/unit conversion. Keep the archive citation separate from the provider homepage.
#
# | Included example metadata | Value |
# |---|---|
# | Status and revision | SYNTHETIC; synthetic-v1 |
# | Creator and method | Invented fixture rows distributed with this repository; no live source or external data collection |
# | Format | UTF-8 CSV; header row; empty strings preserve missingness |
# | Stable input inventory | [Source manifest](https://github.com/sunshineluyao/Web3AI4IO-SD-Template/blob/9af469f9ede69dc6ed3daef7fbc9fc5fe3d75f1d/metadata/on_chain_source_manifest.json) |
# | Variables, types, units and missing-value meaning | [Data dictionary](https://github.com/sunshineluyao/Web3AI4IO-SD-Template/blob/9af469f9ede69dc6ed3daef7fbc9fc5fe3d75f1d/metadata/data_dictionary.csv) |
# | File-stage documentation | [Track data README](https://github.com/sunshineluyao/Web3AI4IO-SD-Template/blob/9af469f9ede69dc6ed3daef7fbc9fc5fe3d75f1d/data/on_chain/README.md) |
# | Rights | [Existing MIT license](https://github.com/sunshineluyao/Web3AI4IO-SD-Template/blob/9af469f9ede69dc6ed3daef7fbc9fc5fe3d75f1d/LICENSE) for included invented fixtures; [real-data license worksheet](https://github.com/sunshineluyao/Web3AI4IO-SD-Template/blob/9af469f9ede69dc6ed3daef7fbc9fc5fe3d75f1d/DATA_LICENSE.md) |
#
# **AUTHOR INPUT:** Replace each example entry with actual source-specific metadata. Use exact item/download/query URLs and versions. Record source creator, retrieval timestamp, update behavior, access restrictions and evidence of redistribution rights. A repository URL alone does not document an external source.

# %% [markdown]
# ### Source location and field interpretation
#
# The demo's original input is [the archived events.csv fixture](https://github.com/sunshineluyao/Web3AI4IO-SD-Template/blob/9af469f9ede69dc6ed3daef7fbc9fc5fe3d75f1d/data/on_chain/data_source/demo/events.csv). The query stage copies these exact bytes into the working queried-data area after checking SHA-256, a fingerprint used to detect changed files. This is archived acquisition, not a simulated successful request to a live provider.
#
# **AUTHOR INPUT:** Add a source catalog with one row per real source and a worked field example. Record stable IDs/foreign keys, data types, units, allowed values, missingness codes and the distinction between raw and derived variables. Use [DATA_README](https://github.com/sunshineluyao/Web3AI4IO-SD-Template/blob/9af469f9ede69dc6ed3daef7fbc9fc5fe3d75f1d/templates/DATA_README.md) as the completion worksheet.

# %% [markdown]
# <a id="part-iii"></a>
# ## Part III — Query or acquire data
#
# First retrieve the exact code version and create a fresh working directory. Then run the acquisition [entry point](https://github.com/sunshineluyao/Web3AI4IO-SD-Template/blob/9af469f9ede69dc6ed3daef7fbc9fc5fe3d75f1d/code/on_chain/query_data/run.py) and [stage instructions](https://github.com/sunshineluyao/Web3AI4IO-SD-Template/blob/9af469f9ede69dc6ed3daef7fbc9fc5fe3d75f1d/code/on_chain/query_data/README.md). The canonical implementation is [pipeline.py](https://github.com/sunshineluyao/Web3AI4IO-SD-Template/blob/9af469f9ede69dc6ed3daef7fbc9fc5fe3d75f1d/code/shared/pipeline.py); the notebook calls repository code so the two do not diverge.
#
# **What happens:** The example reads fixed local source files and checks their hashes. Integration also verifies both upstream manifests. No API request is made after cloning the code. An incorrect or missing input stops execution.
#
# **AUTHOR INPUT for real querying:** Explain the live source URL, endpoint/API version, query parameters, filters, date/block partitions, pagination, rate limits, retry/backoff, resume behavior, failed partitions and coverage checks. Separate archived reproduction from recollection. Use Colab Secrets or environment variables for credentials if needed; never place credentials in cells, outputs or shared files.

# %%
# Setup: obtain the exact public code version. Internet is needed only for this clone.
from pathlib import Path
import csv, hashlib, html, json, os, platform, re, subprocess, sys, tempfile
from datetime import datetime, timezone
try:
    from IPython.display import HTML, display
except ImportError:  # Plain Python inspection outside Jupyter/Colab.
    HTML = str
    def display(value):
        print(value)

REPO_URL = "https://github.com/sunshineluyao/Web3AI4IO-SD-Template.git"
CODE_COMMIT = "9af469f9ede69dc6ed3daef7fbc9fc5fe3d75f1d"  # Pin a full reviewed commit when adapting the project.
TRACK = "on_chain"
RUN_MODE = "synthetic_demo"
if RUN_MODE != "synthetic_demo":
    raise ValueError("Implement and document the project inputs, commands and references before changing RUN_MODE.")

# Optional local testing path; ordinary Colab users leave this environment variable unset.
local_repo = os.environ.get("WEB3SD_LOCAL_REPO")
RUN_ROOT = Path(tempfile.mkdtemp(prefix="web3sd_" + TRACK + "_"))
if local_repo:
    CODE_DIR = Path(local_repo).resolve()
    print("LOCAL TEST MODE: using", CODE_DIR, "; pinned clone verification not performed")
else:
    if not re.fullmatch(r"[0-9a-f]{40}", CODE_COMMIT):
        raise ValueError("Set CODE_COMMIT to the reviewed full Git commit SHA.")
    CODE_DIR = RUN_ROOT / "code"
    subprocess.run(["git", "clone", "--quiet", REPO_URL, str(CODE_DIR)], check=True)
    subprocess.run(["git", "-C", str(CODE_DIR), "checkout", "--quiet", "--detach", CODE_COMMIT], check=True)
    actual = subprocess.check_output(["git", "-C", str(CODE_DIR), "rev-parse", "HEAD"], text=True).strip()
    if actual != CODE_COMMIT:
        raise ValueError("Code revision mismatch")
WORKDIR = RUN_ROOT / "outputs"
TRACK_DIR = WORKDIR / TRACK
print("Python:", platform.python_version(), "| code:", CODE_COMMIT)
print("Mode:", RUN_MODE, "| data revision: synthetic-v1 | work directory:", WORKDIR)
if sys.version_info[:2] != (3, 12):
    print("Runtime differs from the locally validated Python 3.12. Record it and compare all outputs.")

# %% [markdown]
# ### Author worksheet and reusable helpers
#
# The entries below are editable planning metadata. Filling them does not change the bundled example into empirical research. To adapt this notebook, update the input manifests, canonical stage code, dictionaries, reference outputs, pinned commit, explanations and completion evidence together. Keep the synthetic example separate and rerun the research tutorial independently.

# %%
AUTHOR_INPUT = {
    "project_title": None,
    "lead_author_or_joint_authors": None,
    "independent_reader": None,
    "observation_unit": None,
    "population_and_time_scope": None,
    "real_source_documentation_urls": [],
    "real_data_release_urls_and_versions": [],
    "license_and_access_evidence": None,
    "scientific_validation_evidence": None,
}
print("Unfilled author entries:", [k for k, v in AUTHOR_INPUT.items() if v is None or v == []])

def run_stage(stage):
    script = CODE_DIR / "code" / TRACK / stage / "run.py"
    command = [sys.executable, str(script), "--workdir", str(WORKDIR)]
    print("Running:", " ".join(command))
    subprocess.run(command, cwd=CODE_DIR, check=True)

def read_json(path):
    return json.loads(Path(path).read_text(encoding="utf-8"))

def read_rows(path):
    with Path(path).open(newline="", encoding="utf-8") as handle:
        return list(csv.DictReader(handle))

def show_rows(rows, limit=10):
    if not rows:
        print("No rows; check whether an empty result is expected.")
        return
    fields = list(rows[0])
    header = "".join("<th>" + html.escape(str(k)) + "</th>" for k in fields)
    body = "".join("<tr>" + "".join("<td>" + html.escape(str(r.get(k, ""))) + "</td>" for k in fields) + "</tr>" for r in rows[:limit])
    display(HTML("<table><thead><tr>" + header + "</tr></thead><tbody>" + body + "</tbody></table>"))
    print("Rows:", len(rows), "| showing:", min(limit, len(rows)))

def inspect_csv(path, limit=10):
    rows = read_rows(path)
    print(Path(path).name, "| bytes:", Path(path).stat().st_size)
    show_rows(rows, limit)
    return rows

def show_report(name):
    report = read_json(TRACK_DIR / "reports" / (name + ".json"))
    print(json.dumps(report, indent=2))
    return report

# %% [markdown]
# ### Run acquisition and inspect its receipt
#
# Expected: an acquisition report marked SYNTHETIC and archived_offline, with zero live requests and the exact acquired files and hashes. A receipt describes the run; inspect the files in Part IV to see their contents.

# %%
run_stage("query_data")
acquisition = show_report("acquisition")
assert acquisition["evidence_status"] == "SYNTHETIC"
assert acquisition["live_requests"] == 0

# %% [markdown]
# <a id="part-iv"></a>
# ## Part IV — Inspect queried data
#
# Open the acquired files before transforming them. Compare columns, row counts, sample records, time bounds, identifiers and missing values with the source specification. Do not silently trim fields or convert missing values to zero. [Queried-data documentation](https://github.com/sunshineluyao/Web3AI4IO-SD-Template/blob/9af469f9ede69dc6ed3daef7fbc9fc5fe3d75f1d/data/on_chain/queried_data/README.md).
#
# **AUTHOR INPUT:** Describe one complete source record, its eligible population and what it cannot establish. Record the expected file list/counts from your actual acquisition receipt. Explain duplicates, malformed rows, failed partitions, source overlap and access limitations before processing.

# %%
RAW_FILES = ['events.csv']
queried = {}
for filename in RAW_FILES:
    queried[filename] = inspect_csv(TRACK_DIR / "queried_data" / filename)
print("Input row counts:", {k: len(v) for k, v in queried.items()})

# %%
assert len(queried['events.csv']) == 8
print("Empty cells by field:")
for field in queried['events.csv'][0]:
    print(field, sum(row[field] == "" for row in queried['events.csv']))

# %% [markdown]
# <a id="part-v"></a>
# ## Part V — Process data
#
# The demo removes one exact duplicate by chain/transaction/log index, rejects conflicting duplicates, removes one event whose fixture canonical flag is false, and preserves missing amounts. It does not contact a node or establish real finality.
#
# Run the processing [entry point](https://github.com/sunshineluyao/Web3AI4IO-SD-Template/blob/9af469f9ede69dc6ed3daef7fbc9fc5fe3d75f1d/code/on_chain/process_data/run.py) and [stage instructions](https://github.com/sunshineluyao/Web3AI4IO-SD-Template/blob/9af469f9ede69dc6ed3daef7fbc9fc5fe3d75f1d/code/on_chain/process_data/README.md). It verifies the acquired bytes again and writes new processed files and a count ledger.
#
# **AUTHOR INPUT:** Explain every transformation in execution order, including retained raw fields, identifier normalization, units, duplicate/conflict policy, exclusions, aggregation, missingness and parameter rationale. Include a before/after example and count reconciliation. For integration, jointly explain every matching and temporal decision in plain language.

# %%
run_stage("process_data")
processing = show_report("processing")

# %%
assert processing["raw_rows"] == 8
assert processing["raw_rows"] - processing["exact_duplicates_removed"] - processing["noncanonical_removed"] == processing["processed_rows"] == 6
print("8 input rows - 1 exact duplicate - 1 noncanonical fixture = 6 events.")

# %% [markdown]
# ### Explain a transformation before moving on
#
# **AUTHOR INPUT:** Choose one actual row, identify the rule/code location and original value, describe its output or exclusion, and justify that decision. Explain how an alternative reasonable rule might change the dataset. Retain the evidence path so the other author can check it.

# %% [markdown]
# <a id="part-vi"></a>
# ## Part VI — Inspect processed data
#
# Read the [processed-data documentation](https://github.com/sunshineluyao/Web3AI4IO-SD-Template/blob/9af469f9ede69dc6ed3daef7fbc9fc5fe3d75f1d/data/on_chain/processed_data/README.md) and compare each field with the dictionary. The example expects 6 records in its main processed file. Empty strings are preserved as missing values; interpret them alongside the relevant status and provenance fields.
#
# **AUTHOR INPUT:** Supply a final file inventory, exact revision, rows/objects, primary/foreign keys, schema, units, missingness, checksums and a worked record explanation. Check whether the released observation unit still matches the plan.

# %%
processed = inspect_csv(TRACK_DIR / "processed_data" / 'events.csv')
assert len(processed) == 6
dictionary = read_rows(CODE_DIR / "metadata" / "data_dictionary.csv")
show_rows([r for r in dictionary if r["table"] == TRACK], limit=40)

# %% [markdown]
# ### Component handoff
#
# The archived [component release manifest](https://github.com/sunshineluyao/Web3AI4IO-SD-Template/blob/9af469f9ede69dc6ed3daef7fbc9fc5fe3d75f1d/metadata/on_chain_release_manifest.json) identifies the processed snapshot acquired by the integration tutorial. Your empirical handoff must include actual file hashes and versions, dictionary, source rights, quality evidence and the agreed integration key/time fields.

# %%
component_manifest = read_json(CODE_DIR / "metadata" / "on_chain_release_manifest.json")
print(json.dumps(component_manifest, indent=2))
print("Fresh output SHA-256:", hashlib.sha256((TRACK_DIR / "processed_data" / 'events.csv').read_bytes()).hexdigest())

# %% [markdown]
# <a id="part-vii"></a>
# ## Part VII — Analyze data for understanding and reuse
#
# Describe the included events and distinct contracts. A contract count is not a count of people, organizations or adoption. Show one valid data-use example at the released unit and preserve uncertainty about real-world interpretation.
#
# Run the descriptive analysis [entry point](https://github.com/sunshineluyao/Web3AI4IO-SD-Template/blob/9af469f9ede69dc6ed3daef7fbc9fc5fe3d75f1d/code/on_chain/analyze_data/run.py) and [stage instructions](https://github.com/sunshineluyao/Web3AI4IO-SD-Template/blob/9af469f9ede69dc6ed3daef7fbc9fc5fe3d75f1d/code/on_chain/analyze_data/README.md). Its outputs are teaching summaries. Substantive research questions, causal designs and model evaluations require their own evidence and suitable study design.
#
# **AUTHOR INPUT:** Add one bounded, reproducible reuse example accessible to another discipline. State the question, unit, denominator, assumptions, parameters, interpretation and limitations. Cite the code and output. If using prediction, explain entity/time splits and leakage prevention; if claiming causal effects, provide an independently justified identification design.

# %%
run_stage("analyze_data")
analysis = show_report("analysis")
assert analysis["inference"] == "descriptive_only"

# %%
assert analysis["rows"] == 6
print("Counts describe only the invented fixture; no empirical project result is established.")

# %% [markdown]
# <a id="part-viii"></a>
# ## Part VIII — Technical validation and independent reproduction
#
# There are two different evidence tasks. **Software reproduction** checks whether pinned input bytes and code reproduce the governed output. **Scientific validation** assesses whether real data and relationships are accurate and suitable for stated uses. This example demonstrates the former.
#
# Design independent checks for source coverage, failed partitions, canonicality/reorg handling, decoding and units. Review sampled original records against an independent source where feasible. Specify sample selection, denominator, justified thresholds, uncertainty and limitations. Address chain/provider coverage bias.
#
# Run the technical-validation [entry point](https://github.com/sunshineluyao/Web3AI4IO-SD-Template/blob/9af469f9ede69dc6ed3daef7fbc9fc5fe3d75f1d/code/on_chain/technical_validation/run.py) and [stage instructions](https://github.com/sunshineluyao/Web3AI4IO-SD-Template/blob/9af469f9ede69dc6ed3daef7fbc9fc5fe3d75f1d/code/on_chain/technical_validation/README.md). It compares processed CSVs and processing/analysis reports against the [frozen synthetic reference](https://github.com/sunshineluyao/Web3AI4IO-SD-Template/blob/9af469f9ede69dc6ed3daef7fbc9fc5fe3d75f1d/tests/reference/outputs.json). Complete [VALIDATION_PLAN](https://github.com/sunshineluyao/Web3AI4IO-SD-Template/blob/9af469f9ede69dc6ed3daef7fbc9fc5fe3d75f1d/templates/VALIDATION_PLAN.md) for the research resource; do not replace scientific evidence with a PASS label.

# %%
run_stage("technical_validation")
validation = show_report("validation")
assert validation["reference_comparison"] == "PASS"
assert validation["evidence_status"] == "SYNTHETIC"

# %% [markdown]
# ### Record a fresh run and optionally compare an independent receipt
#
# The next cell writes a small run receipt with code/data revision, runtime and output hashes. A coauthor should run the notebook independently and compare these values. Matching hashes support deterministic reproduction; they do not establish scientific validity. Leave the optional baseline path unset for a first run.

# %%
RUN_RECEIPT = {
    "track": TRACK, "mode": RUN_MODE, "evidence_status": "SYNTHETIC",
    "code_commit": CODE_COMMIT, "code_verification": "local_override" if local_repo else "pinned_checkout",
    "data_revision": "synthetic-v1", "python": platform.python_version(),
    "run_time_utc": datetime.now(timezone.utc).isoformat(),
    "output_sha256": validation["output_sha256"],
    "author_inputs": AUTHOR_INPUT,
    "scientific_validation": "NOT_ESTABLISHED",
}
receipt_path = TRACK_DIR / "reports" / "run_receipt.json"
receipt_path.write_text(json.dumps(RUN_RECEIPT, indent=2) + chr(10), encoding="utf-8")
print("Run receipt:", receipt_path)

BASELINE_RECEIPT_PATH = None  # AUTHOR INPUT: path to a coauthor's independently generated receipt.
if BASELINE_RECEIPT_PATH:
    baseline = read_json(BASELINE_RECEIPT_PATH)
    for key in ["track", "mode", "code_commit", "data_revision", "output_sha256"]:
        if baseline[key] != RUN_RECEIPT[key]:
            raise ValueError("Independent reproduction differs for " + key)
    print("Selected revisions and outputs match the independent receipt.")
else:
    print("Independent receipt comparison not performed; request a coauthor run.")

# %% [markdown]
# ### Optional download of this run's teaching outputs
#
# Only named processed CSVs and reports are packaged. This cell does not upload data or change GitHub/Drive. Set DOWNLOAD_OUTPUTS to True to request a browser download in Colab; otherwise the file is created and its path printed. Review the contents and use a source-approved allowlist when adapting to real data.

# %%
import zipfile
DOWNLOAD_OUTPUTS = False
approved_files = [TRACK_DIR / "processed_data" / name for name in ['events.csv']]
approved_files += [TRACK_DIR / "reports" / (name + ".json") for name in
                  ["acquisition", "processing", "analysis", "validation", "run_receipt"]]
archive = RUN_ROOT / (TRACK + "_synthetic_outputs.zip")
with zipfile.ZipFile(archive, "w", compression=zipfile.ZIP_DEFLATED) as package:
    for path in approved_files:
        if not path.is_file():
            raise FileNotFoundError(path)
        package.write(path, path.relative_to(TRACK_DIR))
print("Created:", archive, "| approved files:", len(approved_files))
if DOWNLOAD_OUTPUTS:
    try:
        from google.colab import files
    except ImportError:
        print("Outside hosted Colab: download the printed archive through your notebook file browser.")
    else:
        files.download(str(archive))

# %% [markdown]
# ### First-author completion and review
#
# Deliver processed events, dictionary, immutable release manifest, acquisition/processing receipts, quality evidence and this edited notebook to Student B and the integration pipeline.
#
# - [ ] Replace every AUTHOR INPUT with verified project content and cite exact artifacts.
# - [ ] Clearly label the actual data status; preserve synthetic examples separately.
# - [ ] Pin code, all input releases and the linkage specification; synchronize paper counts.
# - [ ] Run from a fresh runtime and retain errors, limitations and expected-output evidence.
# - [ ] Complete source-specific rights/access decisions and the scientific validation plan.
# - [ ] Obtain a coauthor's independent run and [review](https://github.com/sunshineluyao/Web3AI4IO-SD-Template/blob/9af469f9ede69dc6ed3daef7fbc9fc5fe3d75f1d/templates/REPRODUCTION_REVIEW.md).
# - [ ] Recheck [venue guidance](https://github.com/sunshineluyao/Web3AI4IO-SD-Template/blob/9af469f9ede69dc6ed3daef7fbc9fc5fe3d75f1d/docs/requirements.md) for the actual submission year.
#
# **AUTHOR INPUT:** State what is complete, what remains unvalidated, the next revision and responsible author. Do not report a hosted Colab or external validation run unless it actually occurred.
#
# Reference shelf: [Scientific Data](https://www.nature.com/sdata/submission-guidelines), [NeurIPS hosting](https://neurips.cc/Conferences/2026/EvaluationsDatasetsHosting), [NeurIPS checklist](https://neurips.cc/public/guides/PaperChecklist), [Colab FAQ](https://research.google.com/colaboratory/faq.html), [project governance](https://github.com/sunshineluyao/Web3AI4IO-SD-Template/blob/9af469f9ede69dc6ed3daef7fbc9fc5fe3d75f1d/docs/governance.md), [reproducibility guide](https://github.com/sunshineluyao/Web3AI4IO-SD-Template/blob/9af469f9ede69dc6ed3daef7fbc9fc5fe3d75f1d/docs/reproducibility.md). Add source/API and methodological references for the actual project here.
